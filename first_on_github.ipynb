# %% [markdown]
# <a href="https://colab.research.google.com/github/mingmingeddiewu/Mycode/blob/main/first_on_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 27 Nov 2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
exam = pd.DataFrame({
    'sub_a': np.random.randint(0, high=100, size=1000),
    'sub_b': np.random.randint(10, high=100, size=1000),
    'sub_c': np.random.randint(0, high=100, size=1000),
    'sub_d': np.random.randint(10, high=80, size=1000),
    'sub_e': np.random.randint(0, high=100, size=1000),
    'sub_f': np.random.randint(20, high=100, size=1000)
})
exam.head(10)
# Out:
#    sub_a  sub_b  sub_c  sub_d  sub_e  sub_f
# 0     25     29     77     16     77     94
# 1     74     40     40     32     87     61
# 2     13     89     89     19     80     96
# 3     75     84     42     19     11     90
# 4     59     90     67     34     31     55
# 5     57     80     27     62     25     56
# 6     98     30     26     33     99     21
# 7     28     45      5     25     48     24
# 8     84     23     29     29     33     34
# 9     66     54     37     25     52     82

# %%
exam.tail(5)
# Out:
#      sub_a  sub_b  sub_c  sub_d  sub_e  sub_f
# 995     56     65     86     72     10     80
# 996     88     49     70     56     39     97
# 997     34     17      8     19     12     85
# 998     85     53     65     39     67     90
# 999     12     13     99     16     96     68

# %%
exam.corr()
# Out:
#           sub_a     sub_b     sub_c     sub_d     sub_e     sub_f
# sub_a  1.000000  0.004747  0.002816  0.041351  0.000400 -0.005940
# sub_b  0.004747  1.000000 -0.048342 -0.015546 -0.036658  0.035766
# sub_c  0.002816 -0.048342  1.000000 -0.033708 -0.028356  0.025624
# sub_d  0.041351 -0.015546 -0.033708  1.000000 -0.032027  0.007566
# sub_e  0.000400 -0.036658 -0.028356 -0.032027  1.000000  0.050165
# sub_f -0.005940  0.035766  0.025624  0.007566  0.050165  1.000000

# %%
sns.boxplot(data=exam)

# %%
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
exam['Mean'] = exam.mean(axis=1)

# %%
exam
# Out:
#      sub_a  sub_b  sub_c  sub_d  sub_e  sub_f       Mean
# 0       25     29     77     16     77     94  53.000000
# 1       74     40     40     32     87     61  55.666667
# 2       13     89     89     19     80     96  64.333333
# 3       75     84     42     19     11     90  53.500000
# 4       59     90     67     34     31     55  56.000000
# ..     ...    ...    ...    ...    ...    ...        ...
# 995     56     65     86     72     10     80  61.500000
# 996     88     49     70     56     39     97  66.500000
# 997     34     17      8     19     12     85  29.166667
# 998     85     53     65     39     67     90  66.500000
# 999     12     13     99     16     96     68  50.666667
#
# [1000 rows x 7 columns]

# %%
round(exam['Mean'])
# Out:
# 0      53.0
# 1      56.0
# 2      64.0
# 3      54.0
# 4      56.0
#        ...
# 995    62.0
# 996    66.0
# 997    29.0
# 998    66.0
# 999    51.0
# Name: Mean, Length: 1000, dtype: float64

# %%
x = exam.drop('Mean', axis=1)
y = exam['Mean']
print(x)
print(y)
# Out:
#      sub_a  sub_b  sub_c  sub_d  sub_e  sub_f
# 0       25     29     77     16     77     94
# 1       74     40     40     32     87     61
# 2       13     89     89     19     80     96
# 3       75     84     42     19     11     90
# 4       59     90     67     34     31     55
# ..     ...    ...    ...    ...    ...    ...
# 995     56     65     86     72     10     80
# 996     88     49     70     56     39     97
# 997     34     17      8     19     12     85
# 998     85     53     65     39     67     90
# 999     12     13     99     16     96     68
#
# [1000 rows x 6 columns]
# 0      53.000000
# 1      55.666667
# 2      64.333333
# 3      53.500000
# 4      56.000000
#          ...
# 995    61.500000
# 996    66.500000
# 997    29.166667
# 998    66.500000
# 999    50.666667
# Name: Mean, Length: 1000, dtype: float64

# %%
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model.fit(x_train, y_train)
prediction = model.predict(x_test)
print(mean_squared_error(prediction, y_test))
print(r2_score(prediction, y_test))
# Out:
# 1.599809915788212e-28
# 1.0

# %%
test = pd.DataFrame({
    'sub_a': np.random.randint(0, high=100, size=10),
    'sub_b': np.random.randint(0, high=100, size=10),
    'sub_c': np.random.randint(0, high=100, size=10),
    'sub_d': np.random.randint(0, high=100, size=10),
    'sub_e': np.random.randint(0, high=100, size=10),
    'sub_f': np.random.randint(0, high=100, size=10)
})
test
# Out:
#    sub_a  sub_b  sub_c  sub_d  sub_e  sub_f
# 0     62     74     50     64     46     13
# 1     55     67     84     62      9     79
# 2     53     49     60     57     53     32
# 3     47     25     11     94     24     78
# 4     11     98     10     46     95     33
# 5     96     32     76     20     16     71
# 6     39     46     68     98     99     77
# 7      8     73      0     55     81     51
# 8     56     41     15     23     46     76
# 9     23      1     28     17     65     30

# %%
model.predict(test)
# Out:
# array([51.5       , 59.33333333, 50.66666667, 46.5       , 48.83333333,
#        51.83333333, 71.16666667, 44.66666667, 42.83333333, 27.33333333])

# %%
test.mean(axis=1)
# Out:
# 0    51.500000
# 1    59.333333
# 2    50.666667
# 3    46.500000
# 4    48.833333
# 5    51.833333
# 6    71.166667
# 7    44.666667
# 8    42.833333
# 9    27.333333
# dtype: float64

# %%
bins = np.linspace(min(exam['Mean']), max(exam['Mean']), 5)
exam['Grade'] = pd.cut(exam['Mean'], bins, labels=['Poor', 'Fair', 'Good', 'Excellent'], include_lowest=True)

# %%
exam.iloc[230:241, :]
# Out:
#      sub_a  sub_b  sub_c  sub_d  sub_e  sub_f       Mean      Grade
# 230     96     80     84     67     35     98  76.666667  Excellent
# 231     59     69     20     18     49     61  46.000000       Fair
# 232     64     71     12     32     98     23  50.000000       Fair
# 233     57     20     73     18     38     27  38.833333       Fair
# 234     39     73     74     79     68     96  71.500000  Excellent
# 235     82     21     63     19     67     76  54.666667       Good
# 236     47     95     36     36     51     55  53.333333       Good
# 237     64     23     88     79      2     41  49.500000       Fair
# 238     37     97     15     62     15     86  52.000000       Good
# 239     30     93     14     59      0     70  44.333333       Fair
# 240     59     77     66     10     17     20  41.500000       Fair

# %%
exam.Grade.value_counts()
# Out:
# Good         444
# Fair         420
# Excellent     72
# Poor          64
# Name: Grade, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
a = exam.drop(['Mean', 'Grade'], axis=1)
b = exam['Grade']
print(a)
print(b)
# Out:
#      sub_a  sub_b  sub_c  sub_d  sub_e  sub_f
# 0       25     29     77     16     77     94
# 1       74     40     40     32     87     61
# 2       13     89     89     19     80     96
# 3       75     84     42     19     11     90
# 4       59     90     67     34     31     55
# ..     ...    ...    ...    ...    ...    ...
# 995     56     65     86     72     10     80
# 996     88     49     70     56     39     97
# 997     34     17      8     19     12     85
# 998     85     53     65     39     67     90
# 999     12     13     99     16     96     68
#
# [1000 rows x 6 columns]
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 995    Good
# 996    Good
# 997    Poor
# 998    Good
# 999    Fair
# Name: Grade, Length: 1000, dtype: category
# Categories (4, object): ['Poor' < 'Fair' < 'Good' < 'Excellent']

# %%
new_model = KNeighborsClassifier()
a_train, a_test, b_train, b_test = train_test_split(a, b, test_size=0.2, random_state=42)
new_model.fit(a_train, b_train)
new_prediction = new_model.predict(a_test)
print(accuracy_score(new_prediction, b_test))
# Out:
# 0.805

# %%
print(classification_report(new_prediction, b_test))
# Out:
#               precision    recall  f1-score   support
#
#    Excellent       0.54      0.88      0.67         8
#         Fair       0.80      0.86      0.83        91
#         Good       0.92      0.74      0.82        92
#         Poor       0.50      0.89      0.64         9
#
#     accuracy                           0.81       200
#    macro avg       0.69      0.84      0.74       200
# weighted avg       0.83      0.81      0.81       200

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(new_prediction, b_test))
# Out:
# [[ 7  0  1  0]
#  [ 0 78  5  8]
#  [ 6 18 68  0]
#  [ 0  1  0  8]]

# %%
from sklearn.linear_model import LogisticRegression

# %%
an_model = LogisticRegression()
an_model.fit(a_train, b_train)
an_prediction = an_model.predict(a_test)
print(accuracy_score(an_prediction, b_test))
# Out:
# 0.8
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
from sklearn.svm import SVC
other_model = SVC()
other_model.fit(a_train, b_train)
other_prediction = other_model.predict(a_test)
print(accuracy_score(other_prediction, b_test))
# Out:
# 0.885

# %%
print(classification_report(other_prediction, b_test))
# Out:
#               precision    recall  f1-score   support
#
#    Excellent       0.54      1.00      0.70         7
#         Fair       0.93      0.90      0.91       100
#         Good       0.97      0.85      0.91        85
#         Poor       0.50      1.00      0.67         8
#
#     accuracy                           0.89       200
#    macro avg       0.73      0.94      0.80       200
# weighted avg       0.92      0.89      0.89       200

# %%
print(confusion_matrix(other_prediction, b_test))
# Out:
# [[ 7  0  0  0]
#  [ 0 90  2  8]
#  [ 6  7 72  0]
#  [ 0  0  0  8]]

# %%
new_model.predict(test)
# Out:
# array(['Good', 'Good', 'Good', 'Fair', 'Fair', 'Good', 'Good', 'Fair',
#        'Fair', 'Fair'], dtype=object)

# %%
other_model.predict(test)
# Out:
# array(['Good', 'Good', 'Fair', 'Fair', 'Fair', 'Good', 'Excellent',
#        'Fair', 'Fair', 'Poor'], dtype=object)

# %%
test.mean(axis=1)
# Out:
# 0    51.500000
# 1    59.333333
# 2    50.666667
# 3    46.500000
# 4    48.833333
# 5    51.833333
# 6    71.166667
# 7    44.666667
# 8    42.833333
# 9    27.333333
# dtype: float64

# %%
icecream = pd.DataFrame({
    'temp': [18, 34, 30, 28, 21, 16, 25, 12],
    'holiday': [1, 1, 0, 1, 0, 1, 0, 1],
    'discount': [1, 1, 0, 0, 1, 1, 0, 0],
    'sale_amount': [410, 550, 400, 380, 450, 220, 200, 240]
})
icecream
# Out:
#    temp  holiday  discount  sale_amount
# 0    18        1         1          410
# 1    34        1         1          550
# 2    30        0         0          400
# 3    28        1         0          380
# 4    21        0         1          450
# 5    16        1         1          220
# 6    25        0         0          200
# 7    12        1         0          240

# %%
from sklearn.preprocessing import StandardScaler

# %%
xx = icecream.drop('sale_amount', axis=1)
yy = icecream['sale_amount']
print(xx)
print(yy)
# Out:
#    temp  holiday  discount
# 0    18        1         1
# 1    34        1         1
# 2    30        0         0
# 3    28        1         0
# 4    21        0         1
# 5    16        1         1
# 6    25        0         0
# 7    12        1         0
# 0    410
# 1    550
# 2    400
# 3    380
# 4    450
# 5    220
# 6    200
# 7    240
# Name: sale_amount, dtype: int64

# %%
scale = StandardScaler()
newxx = scale.fit_transform(xx)
print(newxx)
# Out:
# [[-0.70888121  0.77459667  1.        ]
#  [ 1.55953865  0.77459667  1.        ]
#  [ 0.99243369 -1.29099445 -1.        ]
#  [ 0.70888121  0.77459667 -1.        ]
#  [-0.28355248 -1.29099445  1.        ]
#  [-0.99243369  0.77459667  1.        ]
#  [ 0.28355248 -1.29099445 -1.        ]
#  [-1.55953865  0.77459667 -1.        ]]

# %%
model.fit(newxx, yy)
print(model.intercept_)
print(model.coef_)
# Out:
# 356.25
# [80.02820681 10.62666808 57.01577985]

# %%
new_icecream = pd.DataFrame({
    'temp': [28, 38],
    'holiday': [0, 0],
    'discount': [1, 0]
})
new_icecream
# Out:
#    temp  holiday  discount
# 0    28        0         1
# 1    38        0         0

# %%
new_c = scale.fit_transform(new_icecream)
print(new_c)
# Out:
# [[-1.  0.  1.]
#  [ 1.  0. -1.]]

# %%
model.predict(new_c)
# Out:
# array([333.23757304, 379.26242696])

# %%
icecream
# Out:
#    temp  holiday  discount  sale_amount
# 0    18        1         1          410
# 1    34        1         1          550
# 2    30        0         0          400
# 3    28        1         0          380
# 4    21        0         1          450
# 5    16        1         1          220
# 6    25        0         0          200
# 7    12        1         0          240

# %%
icecream.sort_values(by='sale_amount', ascending=False)
# Out:
#    temp  holiday  discount  sale_amount
# 1    34        1         1          550
# 4    21        0         1          450
# 0    18        1         1          410
# 2    30        0         0          400
# 3    28        1         0          380
# 7    12        1         0          240
# 5    16        1         1          220
# 6    25        0         0          200
